# %% [markdown]
# ## <span style="color:#22d3ee;">What Each Function/Method Is Used For</span>
#
# ### <span style="color:#a78bfa;">NumPy Functions (signature and common args)</span>
# - <span style="color:#60a5fa;"><b>np.arange(start, stop=None, step=1, dtype=None)</b></span>: <span style="color:#fbbf24;"><i>Create evenly spaced values in a range. Args: start, stop, step, dtype.</i></span>
# - <span style="color:#60a5fa;"><b>np.argsort(a, axis=-1, kind="quicksort")</b></span>: <span style="color:#fbbf24;"><i>Return indices that would sort an array. Args: a, axis, kind.</i></span>
# - <span style="color:#60a5fa;"><b>np.array(object, dtype=None, copy=True)</b></span>: <span style="color:#fbbf24;"><i>Convert input data to a NumPy array. Args: object, dtype, copy.</i></span>
# - <span style="color:#60a5fa;"><b>np.array_split(ary, indices_or_sections, axis=0)</b></span>: <span style="color:#fbbf24;"><i>Split array into sub-arrays (unequal allowed). Args: ary, indices_or_sections, axis.</i></span>
# - <span style="color:#60a5fa;"><b>np.concatenate(arrays, axis=0)</b></span>: <span style="color:#fbbf24;"><i>Join arrays along an axis. Args: arrays, axis.</i></span>
# - <span style="color:#60a5fa;"><b>np.diag(v, k=0)</b></span>: <span style="color:#fbbf24;"><i>Create/extract diagonal. Args: v, k.</i></span>
# - <span style="color:#60a5fa;"><b>np.dstack(tup)</b></span>: <span style="color:#fbbf24;"><i>Stack arrays depth-wise (3rd axis). Args: tup (sequence).</i></span>
# - <span style="color:#60a5fa;"><b>np.exp(x)</b></span>: <span style="color:#fbbf24;"><i>Element-wise exponential. Args: x.</i></span>
# - <span style="color:#60a5fa;"><b>np.eye(N, M=None, k=0, dtype=float)</b></span>: <span style="color:#fbbf24;"><i>Create 2D identity matrix. Args: N, M, k, dtype.</i></span>
# - <span style="color:#60a5fa;"><b>np.full(shape, fill_value, dtype=None)</b></span>: <span style="color:#fbbf24;"><i>Create array filled with constant. Args: shape, fill_value, dtype.</i></span>
# - <span style="color:#60a5fa;"><b>np.hsplit(ary, indices_or_sections)</b></span>: <span style="color:#fbbf24;"><i>Split array horizontally (columns). Args: ary, indices_or_sections.</i></span>
# - <span style="color:#60a5fa;"><b>np.hstack(tup)</b></span>: <span style="color:#fbbf24;"><i>Stack arrays horizontally. Args: tup (sequence).</i></span>
# - <span style="color:#60a5fa;"><b>np.insert(arr, obj, values, axis=None)</b></span>: <span style="color:#fbbf24;"><i>Insert values at positions. Args: arr, obj, values, axis.</i></span>
# - <span style="color:#60a5fa;"><b>np.linspace(start, stop, num=50, endpoint=True, dtype=None)</b></span>: <span style="color:#fbbf24;"><i>Evenly spaced numbers. Args: start, stop, num, endpoint, dtype.</i></span>
# - <span style="color:#60a5fa;"><b>np.logspace(start, stop, num=50, endpoint=True, base=10.0)</b></span>: <span style="color:#fbbf24;"><i>Log-spaced numbers. Args: start, stop, num, endpoint, base.</i></span>
# - <span style="color:#60a5fa;"><b>np.maximum(x1, x2)</b></span>: <span style="color:#fbbf24;"><i>Element-wise maximum. Args: x1, x2.</i></span>
# - <span style="color:#60a5fa;"><b>np.mean(a, axis=None, dtype=None)</b></span>: <span style="color:#fbbf24;"><i>Arithmetic mean. Args: a, axis, dtype.</i></span>
# - <span style="color:#60a5fa;"><b>np.minimum(x1, x2)</b></span>: <span style="color:#fbbf24;"><i>Element-wise minimum. Args: x1, x2.</i></span>
# - <span style="color:#60a5fa;"><b>np.nonzero(a)</b></span>: <span style="color:#fbbf24;"><i>Indices of non-zero elements. Args: a.</i></span>
# - <span style="color:#60a5fa;"><b>np.ones(shape, dtype=None)</b></span>: <span style="color:#fbbf24;"><i>Create array of ones. Args: shape, dtype.</i></span>
# - <span style="color:#60a5fa;"><b>np.ravel(a, order="C")</b></span>: <span style="color:#fbbf24;"><i>Flatten to 1D view. Args: a, order.</i></span>
# - <span style="color:#60a5fa;"><b>np.random.rand(d0, d1, ...)</b></span>: <span style="color:#fbbf24;"><i>Uniform random samples in [0, 1). Args: dimensions.</i></span>
# - <span style="color:#60a5fa;"><b>np.random.randint(low, high=None, size=None, dtype=int)</b></span>: <span style="color:#fbbf24;"><i>Random integers. Args: low, high, size, dtype.</i></span>
# - <span style="color:#60a5fa;"><b>np.random.randn(d0, d1, ...)</b></span>: <span style="color:#fbbf24;"><i>Standard normal samples. Args: dimensions.</i></span>
# - <span style="color:#60a5fa;"><b>np.random.seed(seed=None)</b></span>: <span style="color:#fbbf24;"><i>Set random seed. Args: seed.</i></span>
# - <span style="color:#60a5fa;"><b>np.reshape(a, newshape, order="C")</b></span>: <span style="color:#fbbf24;"><i>Change array shape. Args: a, newshape, order.</i></span>
# - <span style="color:#60a5fa;"><b>np.searchsorted(a, v, side="left", sorter=None)</b></span>: <span style="color:#fbbf24;"><i>Insertion indices to keep order. Args: a, v, side, sorter.</i></span>
# - <span style="color:#60a5fa;"><b>np.sort(a, axis=-1)</b></span>: <span style="color:#fbbf24;"><i>Sorted copy. Args: a, axis.</i></span>
# - <span style="color:#60a5fa;"><b>np.split(ary, indices_or_sections, axis=0)</b></span>: <span style="color:#fbbf24;"><i>Split into equal sub-arrays. Args: ary, indices_or_sections, axis.</i></span>
# - <span style="color:#60a5fa;"><b>np.sqrt(x)</b></span>: <span style="color:#fbbf24;"><i>Square root. Args: x.</i></span>
# - <span style="color:#60a5fa;"><b>np.sum(a, axis=None, dtype=None, keepdims=False)</b></span>: <span style="color:#fbbf24;"><i>Sum elements. Args: a, axis, dtype, keepdims.</i></span>
# - <span style="color:#60a5fa;"><b>np.vstack(tup)</b></span>: <span style="color:#fbbf24;"><i>Stack arrays vertically. Args: tup (sequence).</i></span>
# - <span style="color:#60a5fa;"><b>np.vsplit(ary, indices_or_sections)</b></span>: <span style="color:#fbbf24;"><i>Split array vertically. Args: ary, indices_or_sections.</i></span>
# - <span style="color:#60a5fa;"><b>np.where(condition, x=None, y=None)</b></span>: <span style="color:#fbbf24;"><i>Choose values or indices by condition. Args: condition, x, y.</i></span>
# - <span style="color:#60a5fa;"><b>np.zeros(shape, dtype=None)</b></span>: <span style="color:#fbbf24;"><i>Create array of zeros. Args: shape, dtype.</i></span>
#
# ### <span style="color:#a78bfa;">Common ndarray Attributes / Methods</span>
# - <span style="color:#60a5fa;"><b>dtype</b></span>: <span style="color:#fbbf24;"><i>Data type of elements. Attribute (no args).</i></span>
# - <span style="color:#60a5fa;"><b>itemsize</b></span>: <span style="color:#fbbf24;"><i>Bytes per element. Attribute (no args).</i></span>
# - <span style="color:#60a5fa;"><b>nbytes</b></span>: <span style="color:#fbbf24;"><i>Total bytes of elements. Attribute (no args).</i></span>
# - <span style="color:#60a5fa;"><b>ndim</b></span>: <span style="color:#fbbf24;"><i>Number of dimensions. Attribute (no args).</i></span>
# - <span style="color:#60a5fa;"><b>reshape(newshape, order="C")</b></span>: <span style="color:#fbbf24;"><i>Return reshaped view. Args: newshape, order.</i></span>
# - <span style="color:#60a5fa;"><b>shape</b></span>: <span style="color:#fbbf24;"><i>Dimensions of array. Attribute (no args).</i></span>
# - <span style="color:#60a5fa;"><b>size</b></span>: <span style="color:#fbbf24;"><i>Total number of elements. Attribute (no args).</i></span>
# - <span style="color:#60a5fa;"><b>flatten(order="C")</b></span>: <span style="color:#fbbf24;"><i>Return flattened copy. Args: order.</i></span>
# - <span style="color:#60a5fa;"><b>ravel(order="C")</b></span>: <span style="color:#fbbf24;"><i>Return flattened view. Args: order.</i></span>
#
# ### <span style="color:#34d399;">pandas Functions (signature and common args)</span>
# - <span style="color:#2dd4bf;"><b>pd.DataFrame(data=None, index=None, columns=None, dtype=None)</b></span>: <span style="color:#fbbf24;"><i>Create a 2D labeled table. Args: data, index, columns, dtype.</i></span>
# - <span style="color:#2dd4bf;"><b>pd.Series(data=None, index=None, dtype=None, name=None)</b></span>: <span style="color:#fbbf24;"><i>Create a 1D labeled array. Args: data, index, dtype, name.</i></span>
# - <span style="color:#2dd4bf;"><b>pd.concat(objs, axis=0, ignore_index=False, join="outer")</b></span>: <span style="color:#fbbf24;"><i>Concatenate objects. Args: objs, axis, ignore_index, join.</i></span>
# - <span style="color:#2dd4bf;"><b>pd.merge(left, right, how="inner", on=None, left_on=None, right_on=None)</b></span>: <span style="color:#fbbf24;"><i>Database-style join. Args: left, right, how, on, left_on, right_on.</i></span>
# - <span style="color:#2dd4bf;"><b>pd.pivot_table(data, values=None, index=None, columns=None, aggfunc="mean")</b></span>: <span style="color:#fbbf24;"><i>Spreadsheet-like pivot table. Args: data, values, index, columns, aggfunc.</i></span>
# - <span style="color:#2dd4bf;"><b>pd.read_csv(filepath_or_buffer, sep=",", header="infer", names=None)</b></span>: <span style="color:#fbbf24;"><i>Read CSV into DataFrame. Args: filepath_or_buffer, sep, header, names.</i></span>
#
# ### <span style="color:#f97316;">DataFrame / Series Methods and Indexers (signature and common args)</span>
# - <span style="color:#fb923c;"><b>agg(func, axis=0)</b></span>: <span style="color:#fbbf24;"><i>Apply aggregation functions. Args: func, axis.</i></span>
# - <span style="color:#fb923c;"><b>assign(**kwargs)</b></span>: <span style="color:#fbbf24;"><i>Add or modify columns. Args: keyword assignments.</i></span>
# - <span style="color:#fb923c;"><b>bfill(axis=None, limit=None)</b></span>: <span style="color:#fbbf24;"><i>Backward fill missing values. Args: axis, limit.</i></span>
# - <span style="color:#fb923c;"><b>count(axis=0)</b></span>: <span style="color:#fbbf24;"><i>Count non-missing values. Args: axis.</i></span>
# - <span style="color:#fb923c;"><b>describe()</b></span>: <span style="color:#fbbf24;"><i>Summary statistics. No args.</i></span>
# - <span style="color:#fb923c;"><b>drop(labels=None, axis=0, index=None, columns=None, inplace=False)</b></span>: <span style="color:#fbbf24;"><i>Remove rows/columns. Args: labels, axis, index, columns, inplace.</i></span>
# - <span style="color:#fb923c;"><b>drop_duplicates(subset=None, keep="first")</b></span>: <span style="color:#fbbf24;"><i>Remove duplicate rows. Args: subset, keep.</i></span>
# - <span style="color:#fb923c;"><b>dropna(axis=0, how="any", subset=None)</b></span>: <span style="color:#fbbf24;"><i>Drop missing data. Args: axis, how, subset.</i></span>
# - <span style="color:#fb923c;"><b>duplicated(subset=None, keep="first")</b></span>: <span style="color:#fbbf24;"><i>Mark duplicates. Args: subset, keep.</i></span>
# - <span style="color:#fb923c;"><b>ffill(axis=None, limit=None)</b></span>: <span style="color:#fbbf24;"><i>Forward fill missing values. Args: axis, limit.</i></span>
# - <span style="color:#fb923c;"><b>fillna(value=None, method=None, axis=None)</b></span>: <span style="color:#fbbf24;"><i>Fill missing values. Args: value, method, axis.</i></span>
# - <span style="color:#fb923c;"><b>groupby(by=None, axis=0, as_index=True)</b></span>: <span style="color:#fbbf24;"><i>Group for aggregation. Args: by, axis, as_index.</i></span>
# - <span style="color:#fb923c;"><b>head(n=5)</b></span>: <span style="color:#fbbf24;"><i>First rows. Args: n.</i></span>
# - <span style="color:#fb923c;"><b>idxmin(axis=0)</b></span>: <span style="color:#fbbf24;"><i>Index of first minimum. Args: axis.</i></span>
# - <span style="color:#fb923c;"><b>info()</b></span>: <span style="color:#fbbf24;"><i>DataFrame summary. No args.</i></span>
# - <span style="color:#fb923c;"><b>isna()</b></span>: <span style="color:#fbbf24;"><i>Detect missing values. No args.</i></span>
# - <span style="color:#fb923c;"><b>isnull()</b></span>: <span style="color:#fbbf24;"><i>Alias of isna. No args.</i></span>
# - <span style="color:#fb923c;"><b>join(other, on=None, how="left")</b></span>: <span style="color:#fbbf24;"><i>Join columns from another DataFrame. Args: other, on, how.</i></span>
# - <span style="color:#fb923c;"><b>loc[row, col]</b></span>: <span style="color:#fbbf24;"><i>Label-based indexer. Args: row labels, column labels.</i></span>
# - <span style="color:#fb923c;"><b>iloc[row, col]</b></span>: <span style="color:#fbbf24;"><i>Position-based indexer. Args: row positions, column positions.</i></span>
# - <span style="color:#fb923c;"><b>mean(axis=0, numeric_only=None)</b></span>: <span style="color:#fbbf24;"><i>Mean values. Args: axis, numeric_only.</i></span>
# - <span style="color:#fb923c;"><b>nlargest(n, columns)</b></span>: <span style="color:#fbbf24;"><i>Top n largest rows. Args: n, columns.</i></span>
# - <span style="color:#fb923c;"><b>nsmallest(n, columns)</b></span>: <span style="color:#fbbf24;"><i>Top n smallest rows. Args: n, columns.</i></span>
# - <span style="color:#fb923c;"><b>notna()</b></span>: <span style="color:#fbbf24;"><i>Detect non-missing values. No args.</i></span>
# - <span style="color:#fb923c;"><b>notnull()</b></span>: <span style="color:#fbbf24;"><i>Alias of notna. No args.</i></span>
# - <span style="color:#fb923c;"><b>rename(mapper=None, index=None, columns=None)</b></span>: <span style="color:#fbbf24;"><i>Rename labels. Args: mapper, index, columns.</i></span>
# - <span style="color:#fb923c;"><b>reset_index(drop=False)</b></span>: <span style="color:#fbbf24;"><i>Reset index to default. Args: drop.</i></span>
# - <span style="color:#fb923c;"><b>sort_values(by, axis=0, ascending=True)</b></span>: <span style="color:#fbbf24;"><i>Sort by values. Args: by, axis, ascending.</i></span>
# - <span style="color:#fb923c;"><b>strip(to_strip=None)</b></span>: <span style="color:#fbbf24;"><i>Strip whitespace (Series.str.strip). Args: to_strip.</i></span>
# - <span style="color:#fb923c;"><b>sum(axis=0, numeric_only=None)</b></span>: <span style="color:#fbbf24;"><i>Sum values. Args: axis, numeric_only.</i></span>
# - <span style="color:#fb923c;"><b>tail(n=5)</b></span>: <span style="color:#fbbf24;"><i>Last rows. Args: n.</i></span>
# - <span style="color:#fb923c;"><b>unique()</b></span>: <span style="color:#fbbf24;"><i>Unique values (Series). No args.</i></span>
# - <span style="color:#fb923c;"><b>value_counts(normalize=False, sort=True)</b></span>: <span style="color:#fbbf24;"><i>Frequency counts. Args: normalize, sort.</i></span>
#
# ### <span style="color:#f43f5e;">Common Attributes</span>
# - <span style="color:#fb7185;"><b>columns</b></span>: <span style="color:#fbbf24;"><i>Column labels. Attribute (no args).</i></span>
# - <span style="color:#fb7185;"><b>dtypes</b></span>: <span style="color:#fbbf24;"><i>Column data types. Attribute (no args).</i></span>
# - <span style="color:#fb7185;"><b>index</b></span>: <span style="color:#fbbf24;"><i>Row index. Attribute (no args).</i></span>
# - <span style="color:#fb7185;"><b>shape</b></span>: <span style="color:#fbbf24;"><i>Dimensions of DataFrame/Series. Attribute (no args).</i></span>
# - <span style="color:#fb7185;"><b>values</b></span>: <span style="color:#fbbf24;"><i>Underlying NumPy array. Attribute (no args).</i></span>

# %% [markdown]
# ## <span style="color:#22d3ee;">5) Matplotlib_Seaborn_Combined</span>
#
# ### <span style="color:#34d399;">Seaborn Functions (signature and common args)</span>
# - <span style="color:#38bdf8;"><b>sns.load_dataset(name, cache=True, data_home=None)</b></span>: <span style="color:#fbbf24;"><i>Load a built-in dataset by name. Args: name (string), cache (bool), data_home (path).</i></span>
# - <span style="color:#38bdf8;"><b>sns.scatterplot(x=None, y=None, data=None, hue=None, style=None, size=None, ax=None)</b></span>: <span style="color:#fbbf24;"><i>Scatter plot of two numeric variables. Args: x, y, data, hue, style, size, ax.</i></span>
# - <span style="color:#38bdf8;"><b>sns.barplot(x=None, y=None, data=None, hue=None, estimator="mean", ci=95, ax=None)</b></span>: <span style="color:#fbbf24;"><i>Category-wise aggregate bar chart. Args: x, y, data, hue, estimator, ci, ax.</i></span>
# - <span style="color:#38bdf8;"><b>sns.boxplot(x=None, y=None, data=None, hue=None, ax=None)</b></span>: <span style="color:#fbbf24;"><i>Distribution with median and quartiles. Args: x, y, data, hue, ax.</i></span>
# - <span style="color:#38bdf8;"><b>sns.histplot(data=None, x=None, y=None, bins=None, kde=False, ax=None)</b></span>: <span style="color:#fbbf24;"><i>Histogram of a variable. Args: data, x, y, bins, kde, ax.</i></span>
# - <span style="color:#38bdf8;"><b>sns.pairplot(data, hue=None, kind="scatter", diag_kind="hist", palette=None)</b></span>: <span style="color:#fbbf24;"><i>Pairwise plots for numeric columns. Args: data, hue, kind, diag_kind, palette.</i></span>
# - <span style="color:#38bdf8;"><b>sns.heatmap(data, annot=False, fmt=".2f", cmap=None, ax=None)</b></span>: <span style="color:#fbbf24;"><i>Heatmap for matrix-like data. Args: data, annot, fmt, cmap, ax.</i></span>
# - <span style="color:#38bdf8;"><b>sns.kdeplot(data=None, x=None, y=None, fill=False, ax=None)</b></span>: <span style="color:#fbbf24;"><i>Smooth density curve. Args: data, x, y, fill, ax.</i></span>
# - <span style="color:#38bdf8;"><b>sns.countplot(data=None, x=None, y=None, hue=None, order=None, ax=None)</b></span>: <span style="color:#fbbf24;"><i>Count of categories. Args: data, x or y, hue, order, ax.</i></span>
# - <span style="color:#38bdf8;"><b>sns.set_style(style=None, rc=None)</b></span>: <span style="color:#fbbf24;"><i>Apply a global style theme. Args: style, rc (dict of overrides).</i></span>
#
# ### <span style="color:#a78bfa;">Matplotlib (pyplot) Functions (signature and common args)</span>
# - <span style="color:#60a5fa;"><b>plt.plot(x, y=None, fmt="", data=None, linewidth=None, linestyle=None, marker=None, color=None)</b></span>: <span style="color:#fbbf24;"><i>Line or marker plot. Args: x, y, fmt, linewidth, linestyle, marker, color.</i></span>
# - <span style="color:#60a5fa;"><b>plt.scatter(x, y, s=None, c=None, cmap=None, alpha=None)</b></span>: <span style="color:#fbbf24;"><i>Scatter plot. Args: x, y, s (size), c (color), cmap, alpha.</i></span>
# - <span style="color:#60a5fa;"><b>plt.bar(x, height, width=0.8, bottom=None, color=None)</b></span>: <span style="color:#fbbf24;"><i>Vertical bars. Args: x, height, width, bottom, color.</i></span>
# - <span style="color:#60a5fa;"><b>plt.barh(y, width, height=0.8, left=None, color=None)</b></span>: <span style="color:#fbbf24;"><i>Horizontal bars. Args: y, width, height, left, color.</i></span>
# - <span style="color:#60a5fa;"><b>plt.hist(x, bins=None, range=None, alpha=None)</b></span>: <span style="color:#fbbf24;"><i>Histogram. Args: x, bins, range, alpha.</i></span>
# - <span style="color:#60a5fa;"><b>plt.boxplot(x, vert=True, patch_artist=False)</b></span>: <span style="color:#fbbf24;"><i>Box-and-whisker plot. Args: x, vert, patch_artist.</i></span>
# - <span style="color:#60a5fa;"><b>plt.pie(x, labels=None, autopct=None, startangle=0)</b></span>: <span style="color:#fbbf24;"><i>Pie chart. Args: x, labels, autopct, startangle.</i></span>
# - <span style="color:#60a5fa;"><b>plt.imshow(X, cmap=None, aspect=None)</b></span>: <span style="color:#fbbf24;"><i>Render 2D array as image. Args: X, cmap, aspect.</i></span>
# - <span style="color:#60a5fa;"><b>plt.subplots(nrows=1, ncols=1, figsize=None, sharex=False, sharey=False)</b></span>: <span style="color:#fbbf24;"><i>Create a figure and axes grid. Args: nrows, ncols, figsize, sharex, sharey.</i></span>
# - <span style="color:#60a5fa;"><b>plt.figure(figsize=None, dpi=None)</b></span>: <span style="color:#fbbf24;"><i>Create a new figure. Args: figsize, dpi.</i></span>
# - <span style="color:#60a5fa;"><b>plt.title(label, fontsize=None)</b></span>: <span style="color:#fbbf24;"><i>Set plot title. Args: label, fontsize.</i></span>
# - <span style="color:#60a5fa;"><b>plt.suptitle(t, y=0.98, fontsize=None)</b></span>: <span style="color:#fbbf24;"><i>Set figure-wide title. Args: t, y, fontsize.</i></span>
# - <span style="color:#60a5fa;"><b>plt.xlabel(xlabel, fontsize=None)</b></span>: <span style="color:#fbbf24;"><i>Set x-axis label. Args: xlabel, fontsize.</i></span>
# - <span style="color:#60a5fa;"><b>plt.ylabel(ylabel, fontsize=None)</b></span>: <span style="color:#fbbf24;"><i>Set y-axis label. Args: ylabel, fontsize.</i></span>
# - <span style="color:#60a5fa;"><b>plt.xticks(ticks=None, labels=None, rotation=0)</b></span>: <span style="color:#fbbf24;"><i>Set x ticks and labels. Args: ticks, labels, rotation.</i></span>
# - <span style="color:#60a5fa;"><b>plt.yticks(ticks=None, labels=None, rotation=0)</b></span>: <span style="color:#fbbf24;"><i>Set y ticks and labels. Args: ticks, labels, rotation.</i></span>
# - <span style="color:#60a5fa;"><b>plt.legend(labels=None, loc=None)</b></span>: <span style="color:#fbbf24;"><i>Show legend. Args: labels, loc.</i></span>
# - <span style="color:#60a5fa;"><b>plt.grid(visible=True, which="major", axis="both")</b></span>: <span style="color:#fbbf24;"><i>Toggle grid lines. Args: visible, which, axis.</i></span>
# - <span style="color:#60a5fa;"><b>plt.colorbar(mappable=None, ax=None, label=None)</b></span>: <span style="color:#fbbf24;"><i>Add a colorbar. Args: mappable, ax, label.</i></span>
# - <span style="color:#60a5fa;"><b>plt.tight_layout(pad=1.08)</b></span>: <span style="color:#fbbf24;"><i>Adjust spacing. Args: pad.</i></span>
# - <span style="color:#60a5fa;"><b>plt.savefig(fname, dpi=None, bbox_inches=None)</b></span>: <span style="color:#fbbf24;"><i>Save figure to file. Args: fname, dpi, bbox_inches.</i></span>
# - <span style="color:#60a5fa;"><b>plt.show()</b></span>: <span style="color:#fbbf24;"><i>Display the current figure.</i></span>
#
# ### <span style="color:#f97316;">Axes Object Methods (signature and common args)</span>
# - <span style="color:#fb923c;"><b>ax.plot(x, y=None, linewidth=None, linestyle=None, marker=None, color=None)</b></span>: <span style="color:#fbbf24;"><i>Plot on a specific subplot. Args: x, y, linewidth, linestyle, marker, color.</i></span>
# - <span style="color:#fb923c;"><b>ax.scatter(x, y, s=None, c=None, cmap=None, alpha=None)</b></span>: <span style="color:#fbbf24;"><i>Scatter on a specific subplot. Args: x, y, s, c, cmap, alpha.</i></span>
# - <span style="color:#fb923c;"><b>ax.hist(x, bins=None, range=None, alpha=None)</b></span>: <span style="color:#fbbf24;"><i>Histogram on a specific subplot. Args: x, bins, range, alpha.</i></span>
# - <span style="color:#fb923c;"><b>ax.set_title(label, fontsize=None)</b></span>: <span style="color:#fbbf24;"><i>Set subplot title. Args: label, fontsize.</i></span>
# - <span style="color:#fb923c;"><b>ax.set_xlabel(xlabel, fontsize=None)</b></span>: <span style="color:#fbbf24;"><i>Set subplot x label. Args: xlabel, fontsize.</i></span>
# - <span style="color:#fb923c;"><b>ax.set_ylabel(ylabel, fontsize=None)</b></span>: <span style="color:#fbbf24;"><i>Set subplot y label. Args: ylabel, fontsize.</i></span>
# - <span style="color:#fb923c;"><b>ax.legend(labels=None, loc=None)</b></span>: <span style="color:#fbbf24;"><i>Show subplot legend. Args: labels, loc.</i></span>
# - <span style="color:#fb923c;"><b>ax.grid(visible=True, which="major", axis="both")</b></span>: <span style="color:#fbbf24;"><i>Toggle subplot grid. Args: visible, which, axis.</i></span>
#
# ### <span style="color:#f43f5e;">Common Data/Utility Methods Seen (signature and common args)</span>
# - <span style="color:#fb7185;"><b>DataFrame.groupby(by, axis=0, sort=True, as_index=True)</b></span>: <span style="color:#fbbf24;"><i>Group rows for aggregation. Args: by, axis, sort, as_index.</i></span>
# - <span style="color:#fb7185;"><b>DataFrame.mean(axis=0, numeric_only=None)</b></span>: <span style="color:#fbbf24;"><i>Compute mean values. Args: axis, numeric_only.</i></span>
# - <span style="color:#fb7185;"><b>DataFrame.value_counts(subset=None, sort=True, normalize=False)</b></span>: <span style="color:#fbbf24;"><i>Count unique rows or values. Args: subset, sort, normalize.</i></span>
# - <span style="color:#fb7185;"><b>DataFrame.corr(numeric_only=False, method="pearson")</b></span>: <span style="color:#fbbf24;"><i>Correlation matrix. Args: numeric_only, method.</i></span>
# - <span style="color:#fb7185;"><b>DataFrame.pivot(index=None, columns=None, values=None)</b></span>: <span style="color:#fbbf24;"><i>Reshape long to wide. Args: index, columns, values.</i></span>
# - <span style="color:#fb7185;"><b>DataFrame.head(n=5)</b></span>: <span style="color:#fbbf24;"><i>Show first rows. Args: n.</i></span>
# - <span style="color:#fb7185;"><b>np.linspace(start, stop, num=50, endpoint=True)</b></span>: <span style="color:#fbbf24;"><i>Evenly spaced values. Args: start, stop, num, endpoint.</i></span>
# - <span style="color:#fb7185;"><b>np.sin(x) / np.cos(x) / np.tan(x) / np.exp(x)</b></span>: <span style="color:#fbbf24;"><i>Transform numeric arrays. Args: x.</i></span>
