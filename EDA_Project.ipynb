# %% [markdown]
# # Exploratory Data Analysis (EDA) on Music and Mental Health Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('mxmh_survey_results.csv')
df.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 0               Yes  ...        Sometimes  Very frequently            Never
# 1                No  ...        Sometimes           Rarely  Very frequently
# 2               Yes  ...            Never           Rarely           Rarely
# 3               Yes  ...        Sometimes            Never            Never
# 4                No  ...  Very frequently  Very frequently            Never
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects  \
# 0                    Sometimes     3.0        0.0      1.0  0.0           NaN
# 1                       Rarely     7.0        2.0      2.0  1.0           NaN
# 2              Very frequently     7.0        7.0     10.0  2.0     No effect
# 3                        Never     9.0        7.0      3.0  3.0       Improve
# 4                       Rarely     7.0        2.0      5.0  9.0       Improve
#
#      Permissions
# 0  I understand.
# 1  I understand.
# 2  I understand.
# 3  I understand.
# 4  I understand.
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    str
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    str
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    str
#  5   Instrumentalist               732 non-null    str
#  6   Composer                      735 non-null    str
#  7   Fav genre                     736 non-null    str
#  8   Exploratory                   736 non-null    str
#  9   Foreign languages             732 non-null    str
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    str
#  12  Frequency [Country]           736 non-null    str
#  13  Frequency [EDM]               736 non-null    str
#  14  Frequency [Folk]              736 non-null    str
#  15  Frequency [Gospel]            736 non-null    str
#  16  Frequency [Hip hop]           736 non-null    str
#  17  Frequency [Jazz]              736 non-null    str
#  18  Frequency [K pop]             736 non-null    str
#  19  Frequency [Latin]             736 non-null    str
#  20  Frequency [Lofi]              736 non-null    str
#  21  Frequency [Metal]             736 non-null    str
#  22  Frequency [Pop]               736 non-null    str
#  23  Frequency [R&B]               736 non-null    str
#  24  Frequency [Rap]               736 non-null    str
#  25  Frequency [Rock]              736 non-null    str
#  26  Frequency [Video game music]  736 non-null    str
#  27  Anxiety                       736 non-null    float64
#  28  Depression                    736 non-null    float64
#  29  Insomnia                      736 non-null    float64
#  30  OCD                           736 non-null    float64
#  31  Music effects                 728 non-null    str
#  32  Permissions                   736 non-null    str
# dtypes: float64(7), str(26)
# memory usage: 189.9 KB

# %%
df.describe()
# Out:
#               Age  Hours per day           BPM     Anxiety  Depression  \
# count  735.000000     736.000000  6.290000e+02  736.000000  736.000000
# mean    25.206803       3.572758  1.589948e+06    5.837636    4.796196
# std     12.054970       3.028199  3.987261e+07    2.793054    3.028870
# min     10.000000       0.000000  0.000000e+00    0.000000    0.000000
# 25%     18.000000       2.000000  1.000000e+02    4.000000    2.000000
# 50%     21.000000       3.000000  1.200000e+02    6.000000    5.000000
# 75%     28.000000       5.000000  1.440000e+02    8.000000    7.000000
# max     89.000000      24.000000  1.000000e+09   10.000000   10.000000
#
#          Insomnia         OCD
# count  736.000000  736.000000
# mean     3.738451    2.637228
# std      3.088689    2.842017
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    5.000000
# max     10.000000   10.000000

# %%
df.isna()
# Out:
#      Timestamp    Age  Primary streaming service  Hours per day  \
# 0        False  False                      False          False
# 1        False  False                      False          False
# 2        False  False                      False          False
# 3        False  False                      False          False
# 4        False  False                      False          False
# ..         ...    ...                        ...            ...
# 731      False  False                      False          False
# 732      False  False                      False          False
# 733      False  False                      False          False
# 734      False  False                      False          False
# 735      False  False                      False          False
#
#      While working  Instrumentalist  Composer  Fav genre  Exploratory  \
# 0            False            False     False      False        False
# 1            False            False     False      False        False
# 2            False            False     False      False        False
# 3            False            False     False      False        False
# 4            False            False     False      False        False
# ..             ...              ...       ...        ...          ...
# 731          False            False     False      False        False
# 732          False            False     False      False        False
# 733          False            False     False      False        False
# 734          False            False     False      False        False
# 735          False            False     False      False        False
#
#      Foreign languages  ...  Frequency [R&B]  Frequency [Rap]  \
# 0                False  ...            False            False
# 1                False  ...            False            False
# 2                False  ...            False            False
# 3                False  ...            False            False
# 4                False  ...            False            False
# ..                 ...  ...              ...              ...
# 731              False  ...            False            False
# 732              False  ...            False            False
# 733              False  ...            False            False
# 734              False  ...            False            False
# 735              False  ...            False            False
#
#      Frequency [Rock]  Frequency [Video game music]  Anxiety  Depression  \
# 0               False                         False    False       False
# 1               False                         False    False       False
# 2               False                         False    False       False
# 3               False                         False    False       False
# 4               False                         False    False       False
# ..                ...                           ...      ...         ...
# 731             False                         False    False       False
# 732             False                         False    False       False
# 733             False                         False    False       False
# 734             False                         False    False       False
# 735             False                         False    False       False
#
#      Insomnia    OCD  Music effects  Permissions
# 0       False  False           True        False
# 1       False  False           True        False
# 2       False  False          False        False
# 3       False  False          False        False
# 4       False  False          False        False
# ..        ...    ...            ...          ...
# 731     False  False          False        False
# 732     False  False          False        False
# 733     False  False          False        False
# 734     False  False          False        False
# 735     False  False          False        False
#
# [736 rows x 33 columns]

# %%
# Handle missing data
df.dropna(inplace=True)

# %%
sns.set(style="whitegrid")

# %% [markdown]
# ## 1. Music

# %%
sns.histplot(data=df, x='Age', bins=30, color='mediumaquamarine', kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

s_colors = ['lightgreen', 'lightcoral', 'steelblue', 'palevioletred', 'gold', 'darkturquoise']

services = df['Primary streaming service'].value_counts()
services.plot(kind='pie', colors = s_colors)

plt.title('Streaming services by popularity')
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
import seaborn as sns

s_colors2 = ['lightgreen', 'darkturquoise', 'lightcoral', 'steelblue', 'palevioletred', 'gold']

df.replace(['Other streaming service', 'I do not use a streaming service.', 'YouTube Music'],
                       ['Other', 'None', 'YouTube'], inplace=True)

bplot = sns.boxplot(data=df, x="Primary streaming service", y = "Age",
            showfliers = False,
            palette = s_colors2)

plt.title('Streaming services by Age')
# Out:
# C:\Users\nayan\AppData\Local\Temp\ipykernel_25196\3733273024.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bplot = sns.boxplot(data=df, x="Primary streaming service", y = "Age",
# Text(0.5, 1.0, 'Streaming services by Age')

# %%
df.hist(['Hours per day'], bins='auto', density=True, color = 'slateblue', grid=False)
plt.title('Hours spent on music per day')
plt.xlabel('Hours per day')
plt.ylabel('Density')
plt.show()

# %%
df.replace(['No', 'Yes'],
                       [0, 1], inplace=True)
# Out:
#                Timestamp   Age Primary streaming service  Hours per day  \
# 2     8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3     8/27/2022 21:40:40  61.0                   YouTube            2.5
# 4     8/27/2022 21:54:47  18.0                   Spotify            4.0
# 5     8/27/2022 21:56:50  18.0                   Spotify            5.0
# 6     8/27/2022 22:00:29  18.0                   YouTube            3.0
# ..                   ...   ...                       ...            ...
# 731  10/30/2022 14:37:28  17.0                   Spotify            2.0
# 732   11/1/2022 22:26:42  18.0                   Spotify            1.0
# 733   11/3/2022 23:24:38  19.0                     Other            6.0
# 734   11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735    11/9/2022 1:55:20  29.0                   YouTube            2.0
#
#     While working Instrumentalist Composer         Fav genre Exploratory  \
# 2               0               0        0  Video game music           0
# 3               1               0        1              Jazz           1
# 4               1               0        0               R&B           1
# 5               1               1        1              Jazz           1
# 6               1               1        0  Video game music           1
# ..            ...             ...      ...               ...         ...
# 731             1               1        0              Rock           1
# 732             1               1        0               Pop           1
# 733             1               0        1               Rap           1
# 734             1               1        0         Classical           0
# 735             1               0        0           Hip hop           1
#
#     Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 2                   1  ...            Never           Rarely           Rarely
# 3                   1  ...        Sometimes            Never            Never
# 4                   0  ...  Very frequently  Very frequently            Never
# 5                   1  ...  Very frequently  Very frequently  Very frequently
# 6                   1  ...           Rarely            Never            Never
# ..                ...  ...              ...              ...              ...
# 731                 1  ...            Never           Rarely  Very frequently
# 732                 1  ...            Never            Never        Sometimes
# 733                 0  ...        Sometimes        Sometimes           Rarely
# 734                 0  ...            Never            Never            Never
# 735                 1  ...  Very frequently  Very frequently  Very frequently
#
#     Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 2                Very frequently     7.0        7.0     10.0  2.0
# 3                          Never     9.0        7.0      3.0  3.0
# 4                         Rarely     7.0        2.0      5.0  9.0
# 5                          Never     8.0        8.0      7.0  7.0
# 6                      Sometimes     4.0        8.0      6.0  0.0
# ..                           ...     ...        ...      ...  ...
# 731                        Never     7.0        6.0      0.0  9.0
# 732                    Sometimes     3.0        2.0      2.0  5.0
# 733                       Rarely     2.0        2.0      2.0  2.0
# 734                    Sometimes     2.0        3.0      2.0  1.0
# 735                       Rarely     2.0        2.0      2.0  5.0
#
#     Music effects    Permissions
# 2       No effect  I understand.
# 3         Improve  I understand.
# 4         Improve  I understand.
# 5         Improve  I understand.
# 6         Improve  I understand.
# ..            ...            ...
# 731       Improve  I understand.
# 732       Improve  I understand.
# 733       Improve  I understand.
# 734       Improve  I understand.
# 735       Improve  I understand.
#
# [616 rows x 33 columns]

# %%
labels = ['Anxiety', 'Depression','Insomnia', 'OCD']
x = np.arange(len(labels))
width = 0.15

fig, ax = plt.subplots(figsize=(10, 5))

b1 = ax.bar(x-2*width, df[(df.Instrumentalist == 0)].median()[-4:], width, color = 'indianred', label = "Non Instrumentalist")
b2 = ax.bar(x-width, df[(df.Instrumentalist == 1)].median()[-4:], width, color = 'darkred', label = "Instrumentalist")
b3 = ax.bar(x, df[(df.Composer == 0)].median()[-4:], width, color = 'cornflowerblue', label = "Non Composer")
b4 = ax.bar(x+width, df[(df.Composer == 1)].median()[-4:], width, color = 'darkblue', label = "Composer")

ax.set_ylim([0, 8])
ax.set_ylabel('Ranking')
ax.set_title('Mental health ranking distribution')
ax.set_xticks(x, labels)
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 7
#       3 width = 0.15
#       5 fig, ax = plt.subplots(figsize=(10, 5))
# ----> 7 b1 = ax.bar(x-2*width, df[(df.Instrumentalist == 0)].median()[-4:], width, color = 'indianred', label = "Non Instrumentalist")
#       8 b2 = ax.bar(x-width, df[(df.Instrumentalist == 1)].median()[-4:], width, color = 'darkred', label = "Instrumentalist")
#       9 b3 = ax.bar(x, df[(df.Composer == 0)].median()[-4:], width, color = 'cornflowerblue', label = "Non Composer")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:14582, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   14499 @deprecate_nonkeyword_arguments(
#   14500     Pandas4Warning, allowed_args=["self"], name="median"
#   14501 )
#    (...)  14507     **kwargs,
#   14508 ) -> Series | Any:
#   14509     """
#   14510     Return the median of the values over the requested axis.
#   14511
#    (...)  14580     dtype: float64
#   14581     """
# > 14582     result = super().median(
#   14583         axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#   14584     )
#   14585     if isinstance(result, Series):
#   14586         result = result.__finalize__(self, method="median")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:11843, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11835 def median(
#   11836     self,
#   11837     *,
#    (...)  11841     **kwargs,
#   11842 ) -> Series | float:
# > 11843     return self._stat_function(
#   11844         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   11845     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:11785, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11781 nv.validate_func(name, (), kwargs)
#   11783 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11785 return self._reduce(
#   11786     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11787 )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:13617, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   13613     df = df.T
#   13615 # After possibly _get_data and transposing, we are now in the
#   13616 #  simple case where we can use BlockManager.reduce
# > 13617 res = df._mgr.reduce(blk_func)
#   13618 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   13619 out.name = None
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.reduce(self, func)
#    1653 # If 2D, we assume that we're operating column-wise
#    1654 assert self.ndim == 2
# -> 1656 res_blocks = [blk.reduce(func) for blk in self.blocks]
#    1657 index = default_index(1)  # placeholder
#    1658 # shallow copy self.items not needed because DataFrame._reduce does a getitem
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\internals\blocks.py:358, in Block.reduce(self, func)
#     352 @final
#     353 def reduce(self, func) -> Block:
#     354     # We will apply the function and reshape the result into a single-row
#     355     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     356     assert self.ndim == 2
# --> 358     result = func(self.values)
#     360     if self.values.ndim == 1:
#     361         res_values = result
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:13545, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   13543     if not is_1d_only_ea_dtype(values.dtype):
#   13544         return values._reduce(name, axis=1, skipna=skipna, **kwds)
# > 13545     return values._reduce(name, skipna=skipna, keepdims=True, **kwds)
#   13546 else:
#   13547     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\arrays\string_.py:967, in StringArray._reduce(self, name, skipna, keepdims, axis, **kwargs)
#     964         return self._from_sequence([result], dtype=self.dtype)
#     965     return result
# --> 967 raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#
# TypeError: Cannot perform reduction 'median' with string dtype
