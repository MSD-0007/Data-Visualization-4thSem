# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flowers_df = sns.load_dataset('iris')
flowers_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# -------------------------------------------------------------
# 1. SETUP & LOAD DATASET
# -------------------------------------------------------------
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

# Load the iris dataset into a pandas DataFrame
iris = load_iris(as_frame=True)
df = iris.frame

# Display first 5 rows
print("Dataset preview:")
display(df.head())

print("\nColumns:", list(df.columns))
print("Target classes:", iris.target_names)
# Out:
# Dataset preview:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# Columns: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)', 'target']
# Target classes: ['setosa' 'versicolor' 'virginica']

# %%
# -------------------------------------------------------------
# 2. LINE PLOT
# -------------------------------------------------------------
# Line plots are used when data points are connected — showing change or trend.

plt.plot(df.index, df["sepal length (cm)"], color='blue')

plt.title("Line Plot - Sepal Length over Samples")
plt.xlabel("Sample Index")
plt.ylabel("Sepal Length (cm)")
plt.grid(True)
plt.show()

# 💡 Explanation:
# Each point represents one flower’s sepal length.
# The line connects them in order, showing variation or trend.
# Useful for time series or ordered data.

# %%
plt.scatter(df["sepal length (cm)"], df["sepal width (cm)"], color='green')

plt.title("Scatter Plot - Sepal Length vs Sepal Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.grid(True)
plt.show()

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
plt.hist(df["petal width (cm)"], bins=15, color='purple', edgecolor='black', alpha=0.7)

plt.title("Histogram - Petal Width Distribution")
plt.xlabel("Petal Width (cm)")
plt.ylabel("Frequency")
plt.show()

# %%
species_counts = df["target"].value_counts()
plt.pie(species_counts, labels=iris.target_names, autopct="%1.1f%%", startangle=180)
plt.title("Pie Chart - Species Distribution")
plt.show()

# %%
# Seaborn has several small example datasets like "tips", "iris", "penguins", etc.
# Here we load the "tips" dataset which contains information about restaurant bills.

tips = sns.load_dataset("tips")

# Display first few rows to understand the data
tips.head()

# Columns:
# total_bill – total amount of the bill
# tip – tip given by customer
# sex – gender of server
# smoker – whether the customer was a smoker
# day – day of the week
# time – Lunch or Dinner
# size – number of people in the group
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width, hue=flowers_df.species, s=50);

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
plt.hist(setosa_df.sepal_width, bins=np.arange(2, 5, 0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
