# %% [markdown]
# # Functions and Methods Index (Drive Notebooks)
#
# This notebook contains a topic-wise list of functions and methods found in:
# - Numpy_DS_1.ipynb
# - Numpy_DS_2.ipynb
# - Pandas_ALL.ipynb
# - Reading_File.ipynb

# %% [markdown]
# ## 1) Numpy_DS_1
#
# ### NumPy / Module-Level Functions
# - np.arange
# - np.array
# - np.diag
# - np.eye
# - np.full
# - np.linspace
# - np.logspace
# - np.ones
# - np.random.rand
# - np.random.randint
# - np.random.randn
# - np.random.seed
# - np.reshape
# - np.sum
# - np.zeros
#
# ### Common ndarray Attributes / Methods
# - dtype
# - itemsize
# - nbytes
# - ndim
# - reshape
# - shape
# - size

# %% [markdown]
# ## 2) Numpy_DS_2
#
# ### NumPy / Module-Level Functions
# - np.arange
# - np.argsort
# - np.array
# - np.array_split
# - np.concatenate
# - np.dstack
# - np.exp
# - np.flatten
# - np.hsplit
# - np.hstack
# - np.insert
# - np.maximum
# - np.mean
# - np.minimum
# - np.nonzero
# - np.ravel
# - np.reshape
# - np.searchsorted
# - np.sort
# - np.split
# - np.sqrt
# - np.sum
# - np.vstack
# - np.vsplit
# - np.where
#
# ### Common ndarray Attributes / Methods
# - flatten
# - ravel
# - reshape
# - shape

# %% [markdown]
# ## 3) Pandas_ALL
#
# ### pandas / NumPy Functions
# - pd.DataFrame
# - pd.Series
# - pd.concat
# - pd.merge
# - np.where
#
# ### DataFrame / Series Methods and Indexers
# - agg
# - assign
# - bfill
# - describe
# - drop
# - dropna
# - ffill
# - fillna
# - groupby
# - head
# - iloc
# - info
# - isna
# - isnull
# - loc
# - mean
# - notna
# - notnull
# - rename
# - reset_index
# - sort_values
# - sum
# - tail
# - value_counts
#
# ### Common Attributes
# - columns
# - dtypes
# - index
# - shape
# - values

# %% [markdown]
# ## 4) Reading_File
#
# ### pandas Functions
# - pd.DataFrame
# - pd.pivot_table
# - pd.read_csv
#
# ### DataFrame / Series Methods and Indexers
# - agg
# - count
# - describe
# - drop_duplicates
# - duplicated
# - fillna
# - groupby
# - head
# - idxmin
# - info
# - isna
# - isnull
# - join
# - loc
# - mean
# - nlargest
# - nsmallest
# - reset_index
# - sort_values
# - strip
# - sum
# - tail
# - unique
# - value_counts
#
# ### Common Attributes
# - columns
# - shape
# - values

# %%
# Optional: structured dictionary version for quick lookup
functions_methods_index = {
    'Numpy_DS_1': {
        'functions': ['np.arange', 'np.array', 'np.diag', 'np.eye', 'np.full', 'np.linspace', 'np.logspace', 'np.ones', 'np.random.rand', 'np.random.randint', 'np.random.randn', 'np.random.seed', 'np.reshape', 'np.sum', 'np.zeros'],
        'methods_or_attrs': ['dtype', 'itemsize', 'nbytes', 'ndim', 'reshape', 'shape', 'size']
    },
    'Numpy_DS_2': {
        'functions': ['np.arange', 'np.argsort', 'np.array', 'np.array_split', 'np.concatenate', 'np.dstack', 'np.exp', 'np.flatten', 'np.hsplit', 'np.hstack', 'np.insert', 'np.maximum', 'np.mean', 'np.minimum', 'np.nonzero', 'np.ravel', 'np.reshape', 'np.searchsorted', 'np.sort', 'np.split', 'np.sqrt', 'np.sum', 'np.vstack', 'np.vsplit', 'np.where'],
        'methods_or_attrs': ['flatten', 'ravel', 'reshape', 'shape']
    },
    'Pandas_ALL': {
        'functions': ['pd.DataFrame', 'pd.Series', 'pd.concat', 'pd.merge', 'np.where'],
        'methods_or_attrs': ['agg', 'assign', 'bfill', 'columns', 'describe', 'drop', 'dropna', 'dtypes', 'ffill', 'fillna', 'groupby', 'head', 'iloc', 'index', 'info', 'isna', 'isnull', 'loc', 'mean', 'notna', 'notnull', 'rename', 'reset_index', 'shape', 'sort_values', 'sum', 'tail', 'value_counts', 'values']
    },
    'Reading_File': {
        'functions': ['pd.DataFrame', 'pd.pivot_table', 'pd.read_csv'],
        'methods_or_attrs': ['agg', 'columns', 'count', 'describe', 'drop_duplicates', 'duplicated', 'fillna', 'groupby', 'head', 'idxmin', 'info', 'isna', 'isnull', 'join', 'loc', 'mean', 'nlargest', 'nsmallest', 'reset_index', 'shape', 'sort_values', 'strip', 'sum', 'tail', 'unique', 'value_counts', 'values']
    }
}

functions_methods_index
